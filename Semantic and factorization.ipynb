% %% [markdown]
% Redes bayesianas

% %% [markdown]
% Smenatica basica de una red bayesiana y como se construye

% %% [markdown]
% ¿Que es una red bayesiana?

% %% [markdown]
% A cada uno de los nodos se le asocia una distribucion de probabilidad condicional, en la aprte suprior del grafo oo en los nodos que no son hijos mas bien se encuentran distribuciones de porbabildiad puras sin depender de otras variables mientras que los nodos que son hijos de algunas varaibles deben tener distribuciones de probabildiad condicionales que se conidicionan de hecho de esas variables aleatorias representadas por los nodos padres y por ende de todas sus posibles combinacionaes.

% %% [markdown]
% Se puede aplicar la regla de la cadena para las redes bayesianas la cual procede la regla de la cadena
% estandar en probabilidad, esta regla de la cadena apra las rede bayesianas parte de todas las distribu
% ciones condicionales de los nodos y las multiplcia para hallar la distribucion de proabilidad conjunta
% Esto se realiza como iuna multiplciaciond efactores

% %% [markdown]
% A partir de esta intuición definimos una red Bayesiana como un grafo dirigido y no ciclico G cuyos nodos repr
% sentan variables aleatorias y para cada nodo en el grafo tenemos una distribución de probabilidad condicional
% de ese nodo con sus nodos padres y l a Bn(bayesian network) representa una ditstribución de probabilidad conjunta mediante la regla de la cadena para redes bayesianas que es precisamente la multiplicaicon de todas estas probabilidades condicionales de sus nodos (averiguar si esta es una definición general de probabilidad conjunta o solo se cumple aqui)

% %% [markdown]
% S epuede observar que las BN realmente son distribuciones de probabilidad conjuntas, pues, al ser multiplicación de todas distribuciones de cporbabilidad condicional ella es no negativa que la suma da 1 se puede demostrar unicamente utilizando la definición de la regla de la cadena para una BN

% %% [markdown]
% Una distribución P factoriza a G si se puede expresar a P usando al regla de la cedena para redes bayesianas sabre el grafo G, el primer ejemplo de BN antes de que incluso se le llamara BN fue el genetic inheritance

% %% [markdown]
% Patrones de razonamiento

% %% [markdown]
% Hay muchos tipos de razonamiento, primeramente el razonamiento causal, y en una BN este fluye de maner aintuitiva en dirección causal, el razonamiento de evidencia en donde se va de abajo hacia arriba es decir no causalmente sino de hijos a padres, por último y sin mebargo hay un razonamiento más interesante y que no es tan usual y es el razonamiento intercausal en el cual no solo se evalua una evidencia si no varias al mismo tiempo, sin embargo y lo que si es curisso de ese razonamiento en redes BN es que no es necesario que los nodos tengan alguna relacion para ser metidos como evidencia (mirar un poco mas de este razonamiento), otra forma de razonamiento es al revez de la anterior se toma como evidencia dos hijos en vez de dos padres pero estos hijos no tienen mas en comun que un padre relacionado

% %% [markdown]
% fLUIDO DE INFLUENCIA PROBABILISTICA

% %% [markdown]
% La influencia probabilistica empieza en un nodo y empieza a fluir por todo el grafo hasta alcanzar otro nodo, de esta forma debemos aprender cuando un nodo X puede influir en un nodo Y en una BN, por ejemplo si X es un padre de Y evidentemente puede influenciarla pero si Y es padre de X claor que mediante el razonamiento eviednical puede X influir en Y, de hehco la ifnluencia probabilistica es simetrica, algo que no es tan evidente es cuando dos variables hiajs X Y y tienen el mismo padre, puede X influenciar en Y y la respuesta es si, esto por medio del razonamiento intercausal pero una relación mucho más interesante es cuando tanto X como Y influencian a un hijo W (Estructura V)en este caso no necesariamente X causa una infleunciaen Y

% %% [markdown]
% De esta forma se define el termino de senda aditiva la cual es la situación en la cual se carece de evidencias, siendo una senda una cantidad de nodos unidos por aristas no dirgidas y estoy precismaente significa que se puede recorrer el grafo en ambos sentidos, entonces una senda es aditiva si no tiene estructuras V, por otro lado si existe influromación o evidencia adicional a X y Y podria interrumpirse el flujo de influencia de X a Y en los casos intercausales isn embargo pasa algo interesante y eque cuando se tiene evidencia de las variables internas entre los nodos X y Y si que X puede influeir a Y en un V estructura

% %% [markdown]
% Una senda activa es dada si como primer caso para cualquier V estructura tenemos que el nodo intermedio esta evidenciado o tenemos información de el, y como segundo caso no tenermos ningun Xi evidenciado
